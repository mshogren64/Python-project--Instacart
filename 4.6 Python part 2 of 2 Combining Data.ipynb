# %% [markdown]
#  ### 4.6 (continued) Combining data Part 2<br>
#  Merging orders_products_combined w/df_products_cleaned_no_dups<br>
#  df's imported: df_orders_products_combined, df_prods_checked

# %% [markdown]
# ### Question(3) import orders_products_combined dataframe from the pickle file you just saved.

# %%
## import libraries
import pandas as pd
import numpy as np
import os as os

# %%
path = r'/Users/margoshogren/Desktop/1 Margo-CF Folder/4 Python/4-2023 Instacart Basket Analysis'

# %%
df_orders_products_combined = pd.read_pickle(os.path.join(path,'2 Data','prepared data','order_products_combined.pkl'))

# %% [markdown]
# ### Question(4) Check the shape of imported df

# %%
df_orders_products_combined.shape
# Out:
# (32434489, 12)

# %% [markdown]
# #### Observation: Shape matches combined file exported

# %% [markdown]
# ### Question(5) combine the orders_products_combined dataframe with your products data set.

# %%
df_prods_checked = pd.read_csv(os.path.join(path,'2 Data','prepared data','products_checked.csv'),index_col = False)

# %%
df_prods_checked.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_orders_products_combined.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0           0   2539329        1    prior             1                   2
# 1           0   2539329        1    prior             1                   2
# 2           0   2539329        1    prior             1                   2
# 3           0   2539329        1    prior             1                   2
# 4           0   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered _merge
# 0          0   both
# ...

# %%
df_orders_products_combined.describe()
# Out:
#          Unnamed: 0      order_id       user_id  order_number  \
# count  3.243449e+07  3.243449e+07  3.243449e+07  3.243449e+07
# mean   1.709858e+06  1.710749e+06  1.029372e+05  1.714205e+01
# std    9.864636e+05  9.873007e+05  5.946648e+04  1.753504e+01
# min    0.000000e+00  2.000000e+00  1.000000e+00  1.000000e+00
# 25%    8.556170e+05  8.559430e+05  5.142100e+04  5.000000e+00
# 50%    1.709137e+06  1.711048e+06  1.026110e+05  1.100000e+01
# 75%    2.565949e+06  2.565514e+06  1.543910e+05  2.400000e+01
# max    3.421081e+06  3.421083e+06  2.062090e+05  9.900000e+01
#
#        orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# count        3.243449e+07       3.243449e+07            3.035642e+07
# mean         2.738818e+00       1.342498e+01            1.110407e+01
# std          2.090049e+00       4.246365e+00            8.778914e+00
# min          0.000000e+00       0.000000e+00            0.000000e+00
# ...

# %% [markdown]
# ### drop the 'eval_set' column which is not needed

# %%
df_orders_products_combined = df_orders_products_combined.drop(columns = 'eval_set')

# %%
df_prods_checked.describe()
# Out:
#          Unnamed: 0    product_id      aisle_id  department_id        prices
# count  49672.000000  49672.000000  49672.000000   49672.000000  49672.000000
# mean   24852.005053  24850.349775     67.762442      11.728942      7.680359
# std    14342.265579  14340.705287     38.315784       5.850779      4.199401
# min        0.000000      1.000000      1.000000       1.000000      1.000000
# 25%    12432.750000  12432.750000     35.000000       7.000000      4.100000
# 50%    24851.500000  24850.500000     69.000000      13.000000      7.100000
# 75%    37272.250000  37268.250000    100.000000      17.000000     11.100000
# max    49692.000000  49688.000000    134.000000      21.000000     25.000000

# %%
df_prods_checked.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_prods_checked.drop(columns = ['Unnamed: 0'])
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49667       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49668       49685                 En Croute Roast Hazelnut Cranberry
# 49669       49686                                   Artisan Baguette
# 49670       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49671       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %% [markdown]
# ### Merge orders_products_combined and products_checked on 'product_id'

# %%
df_orders_prods_prods_merged = df_prods_checked.merge(df_orders_products_combined, on = 'product_id')

# %% [markdown]
# ### Question(6) Confirm the results of the merge using the merge flag.

# %%
df_orders_prods_prods_merged.head()
# Out:
#    Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0             0           1  Chocolate Sandwich Cookies        61
# 1             0           1  Chocolate Sandwich Cookies        61
# 2             0           1  Chocolate Sandwich Cookies        61
# 3             0           1  Chocolate Sandwich Cookies        61
# 4             0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  Unnamed: 0_y  order_id  user_id  order_number  \
# 0             19     5.8          1987   3139998      138            28
# 1             19     5.8          1989   1977647      138            30
# 2             19     5.8         11433    389851      709             2
# 3             19     5.8         12198    652770      764             1
# 4             19     5.8         12200   1813452      764             3
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# 0                   6                 11                     3.0
# ...

# %%
df_orders_prods_prods_merged['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
df_orders_prods_prods_merged.describe()
# Out:
#        Unnamed: 0_x    product_id      aisle_id  department_id        prices  \
# count  3.240486e+07  3.240486e+07  3.240486e+07   3.240486e+07  3.240486e+07
# mean   2.560037e+04  2.559866e+04  7.119612e+01   9.919792e+00  7.790180e+00
# std    1.408555e+04  1.408400e+04  3.821139e+01   6.281485e+00  4.242125e+00
# min    0.000000e+00  1.000000e+00  1.000000e+00   1.000000e+00  1.000000e+00
# 25%    1.354400e+04  1.354400e+04  3.100000e+01   4.000000e+00  4.200000e+00
# 50%    2.530300e+04  2.530200e+04  8.300000e+01   9.000000e+00  7.400000e+00
# 75%    3.795100e+04  3.794700e+04  1.070000e+02   1.600000e+01  1.130000e+01
# max    4.969200e+04  4.968800e+04  1.340000e+02   2.100000e+01  2.500000e+01
#
#        Unnamed: 0_y      order_id       user_id  order_number  \
# count  3.240486e+07  3.240486e+07  3.240486e+07  3.240486e+07
# mean   1.709858e+06  1.710745e+06  1.029372e+05  1.714230e+01
# std    9.864575e+05  9.872988e+05  5.946610e+04  1.753532e+01
# ...

# %%
df_orders_prods_prods_merged.loc[df_orders_prods_prods_merged['prices'] > 50]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0_x, product_id, product_name, aisle_id, department_id, prices, Unnamed: 0_y, order_id, user_id, order_number, orders_day_of_week, order_hour_of_day, days_since_prior_order, add_to_cart_order, reordered, _merge]
# Index: []

# %% [markdown]
#     ### Question(6) continued- Check the outer join merge counts to show the information found in both data sets.

# %%
df_orders_prods_prods_merged_otr = df_prods_checked.merge(df_orders_products_combined, on = 'product_id', how = 'outer')

# %%
df_orders_prods_prods_merged_otr['_merge'].value_counts()
# Out:
# both          32435059
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %% [markdown]
# #### Observation: The inner and outer join statements for the merge of orders_products_combined and products checked show a full match with the product_id.

# %% [markdown]
# ### Question(7) Export the joined orders-products merge as a pickle file

# %%
df_orders_prods_prods_merged.to_pickle(os.path.join(path,'2 Data','prepared data','orders_products_merged.pkl'))

# %% [markdown]
# #### -End of  4.6 Notebook Combining Data-part 2
